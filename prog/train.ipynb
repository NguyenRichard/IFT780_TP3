# %% [markdown]
# ### Training model

# %%
# !python train.py acdc_train --data_aug --model=FullNet --dgr=4 --dnl=4 --load_checkpoint --save_checkpoint --dataset='./02Heart.hdf5' --num-epochs=10 --batch_size=2
# Out:
# Using data augmentation
# Training FullNet for 10 epochs
# Epoch: 1 of 10
#   0%|                                                   | 0/640 [00:00<?, ?it/s]Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#  10%|██▊                           | 61/640 [00:12<01:51,  5.17it/s, loss=0.225]^C
#  10%|██▉                           | 62/640 [00:12<01:56,  4.96it/s, loss=0.223]
# Traceback (most recent call last):
#   File "train.py", line 159, in <module>
#     model_trainer.train(num_epochs)
#   File "/home/utilisateur/Documents/tp3_ts_tc_rn/prog/CNNTrainTestManager.py", line 171, in train
#     self.optimizer.step()
#   File "/home/utilisateur/Documents/tp3_ts_tc_rn/prog/env/lib/python3.8/site-packages/torch/optim/optimizer.py", line 88, in wrapper
#     return func(*args, **kwargs)
#   File "/home/utilisateur/Documents/tp3_ts_tc_rn/prog/env/lib/python3.8/site-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/utilisateur/Documents/tp3_ts_tc_rn/prog/env/lib/python3.8/site-packages/torch/optim/adam.py", line 141, in step
#     F.adam(params_with_grad,
#   File "/home/utilisateur/Documents/tp3_ts_tc_rn/prog/env/lib/python3.8/site-packages/torch/optim/_functional.py", line 97, in adam
#     exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# KeyboardInterrupt

# %% [markdown]
# **For some unknown reasons matplotlib doesn't plot figures in google colab, so in ohter to visualize the plots we need to save figure as png first and then plot it using the below snippet of code**

# %%
from IPython.display import Image
Image('acdc_train/fig2.png')
